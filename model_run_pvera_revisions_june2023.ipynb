# %%
# %run /g/data/e14/cp3790/Charuni/ModelExperiment/model-run-function-definitions.ipynb

# %% [markdown]
# ## RLS

# %%
TEMP_VAR = "rls"

#Alt 
alt_year_xr_map = get_alt_year_xr_map(
    TEMP_VAR,
    "/g/data/e14/cp3790/Charuni/ModelRun/alt-runs/um_pvera_{}.nc")  

# Con

# bundle info
bundle_1980 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1980/um_pvera_*.nc')
bundle_1999 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1999/um_pvera_*.nc')
con_bundles = {
    '1980': {
        'xr': bundle_1980,
        'start': 1981,
        'end': 1998,
    },
    '1999': {
        'xr': bundle_1999,
        'start': 2000,
        'end': 2018,
    }
}

con_year_xr_map = get_con_year_xr_map(alt_year_xr_map, con_bundles, TEMP_VAR)

# Diff
diff_year_xr_map = get_diff_year_xr_map(alt_year_xr_map, con_year_xr_map)

# %%
con_lw_year_month_xr = get_year_and_months_xr(con_year_xr_map, con_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
alt_lw_year_month_xr = get_year_and_months_xr(alt_year_xr_map, alt_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
diff_lw_year_month_xr = alt_lw_year_month_xr - con_lw_year_month_xr

# %%
diff_lw_year_month_xr
# Out:
# <xarray.DataArray 'rls' (year: 36, month: 13, latitude: 50, longitude: 110)>
# dask.array<subtract, shape=(36, 13, 50, 110), dtype=float32, chunksize=(1, 1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#   * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#     height     float64 10.0
#     time       (year, month) datetime64[ns] 1981-06-30 1981-07-31 ... 2019-06-30
# Dimensions without coordinates: year, month

# %%
# Untested v

lw_year_phases_xr = get_year_2phases_xr(alt_year_xr_map, diff_year_xr_map)

lw_sig_da = get_sig_da(lw_year_phases_xr)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       1 # Untested v
#       3 lw_year_phases_xr = get_year_2phases_xr(alt_year_xr_map, diff_year_xr_map)
# ----> 5 lw_sig_da = get_sig_da(lw_year_month_xr, dim='month')
#
# TypeError: get_sig_da() got an unexpected keyword argument 'dim'

# %%
import numpy as np

# %%
    
    
    
    data_idx = 0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data.isel(month=data_idx)
            contour = ax[row, col].contourf(
                cur_data.longitude,
                cur_data.latitude,
                cur_data.values,
                levels=np.arange(994.5, 1031, 1),
                add_colorbar=False,
                cmap=plt.cm.get_cmap('plasma_r', 35),
                extend='both'
            )
            
            ax[row, col].coastlines()
            ax[row, col].set_extent([140, 180, -48, -33],crs=ccrs.PlateCarree()) 
            ax[row, col].set_title(months[data_idx])
            
            data_idx += 1
            if data_idx > 11:
                stop_plotting = True
                break
        if stop_plotting:
            break
    

    # Choose the traversal you'd like: 'F' is col-wise, 'C' is row-wise           

    ax_flat = ax.flatten(order='C')    
                
    # Delete any unused axes from the figure, so that they don't show
    # blank x- and y-axis lines
    for _, axis in enumerate(ax_flat[12:]):
        fig.delaxes(axis) 
        
    fig.tight_layout()         
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(995,1035,5),
                        fraction=0.015,aspect=45)
    cbar.set_label(label='Mean surface level pressure (hPa)', fontsize=16)  
    cbar.ax.tick_params(labelsize=14)
       
    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/mon_clim_alt_mslp.png')
    plt.show()

# %%
diff_lw_year_month_sep_feb = [diff_lw_year_month_xr.isel(month=3), diff_lw_year_month_xr.isel(month=4), diff_lw_year_month_xr.isel(month=5), diff_lw_year_month_xr.isel(month=6), 
                              diff_lw_year_month_xr.isel(month=7), diff_lw_year_month_xr.isel(month=8)]
diff_lw_year_month_sep_feb
# Out:
# [<xarray.DataArray 'rls' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-09-30 1982-09-30 ... 2018-09-30
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'rls' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-10-31 1982-10-31 ... 2018-10-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'rls' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-11-30 1982-11-30 ... 2018-11-30
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'rls' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-12-31 1982-12-31 ... 2018-12-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'rls' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1982-01-31 1983-01-31 ... 2019-01-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'rls' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1982-02-28 1983-02-28 ... 2019-02-28
#  Dimensions without coordinates: year]

# %%
diff_lw_year_month_sep_feb[0].mean(dim='year').where(mask).plot()

# %%
## new diff plot (months)

def multiple_plots():
    nrow = 2
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = diff_lw_year_month_sep_feb

    months = ['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    data_idx=0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data
            contour = cur_data[data_idx].mean(dim='year').where(mask).plot(
                ax=ax[row, col],
                cmap=plt.cm.get_cmap('bwr', 17),
                vmin=-8, vmax=8,
                add_colorbar=False,
                extend = 'both'
            )
        
            ax[row, col].contour(
                mask_mean.longitude, 
                mask_mean.latitude,
                mask_mean.values,
                levels=[0.5], 
                cmap='gray')


            ax[row, col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
            ax[row, col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
            ax[row, col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
            ax[row, col].set_title(months[data_idx], fontsize=16)
            
            data_idx += 1
            if data_idx > 5:
                stop_plotting = True
                break
        if stop_plotting:
            break

    fig.tight_layout()
    
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down LW flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)
    
    


    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/mon_Fig4c_aus.png')
    #plt.show()
    #0.035

multiple_plots()
# Out:
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1309193083.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1309193083.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1309193083.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1309193083.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1309193083.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1309193083.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),

# %%
## new diff plot (months)

def multiple_plots():
    nrow = 2
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = diff_lw_year_month_sep_feb

    months = ['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    data_idx=0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data
            contour = cur_data[data_idx].mean(dim='year').where(mask).plot(
                ax=ax[row, col],
                cmap=plt.cm.get_cmap('bwr', 17),
                vmin=-8, vmax=8,
                add_colorbar=False,
                extend = 'both'
            )
        
            ax[row, col].contour(
                mask_mean.longitude, 
                mask_mean.latitude,
                mask_mean.values,
                levels=[0.5], 
                cmap='gray')


            ax[row, col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
            ax[row, col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
            ax[row, col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())
            ax[row, col].set_title(months[data_idx], fontsize=16)
            
            data_idx += 1
            if data_idx > 5:
                stop_plotting = True
                break
        if stop_plotting:
            break

    fig.tight_layout()
    
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down LW flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)
    
    


    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/mon_Fig4c_nz.png')
    #plt.show()
    #0.035

multiple_plots()
# Out:
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1886001557.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1886001557.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1886001557.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1886001557.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1886001557.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1886001557.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),

# %%
## new diff plot (phases)

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = lw_year_phases_xr.mean(dim='time').where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('bwr', 17),
            vmin=-8, vmax=8,
            add_colorbar=False,
            extend = 'both'
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')
        
        phase_mask_mean = lw_sig_da[col].where(mask).mean(dim='time')
        ax[col].contourf(
            phase_mask_mean.longitude,
            phase_mask_mean.latitude,
            phase_mask_mean.values,
            levels=[0.00, 0.05, 1.00],
            hatches=['.', None],
            colors='none',
            add_colorbar=False,
        )

        ax[col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down LW flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/Fig3.8e_aus.png')
    #0.035

multiple_plots()
# Out:
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/3163803735.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/3163803735.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %%
## new diff plot (phases)

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = lw_year_phases_xr.mean(dim='time').where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('bwr', 17),
            vmin=-8, vmax=8,
            add_colorbar=False, 
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')
        
        phase_mask_mean = lw_sig_da[col].where(mask).mean(dim='time')
        ax[col].contourf(
            phase_mask_mean.longitude,
            phase_mask_mean.latitude,
            phase_mask_mean.values,
            levels=[0.00, 0.05, 1.00],
            hatches=['.', None],
            colors='none',
            add_colorbar=False,
        )

        ax[col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down surface longwave radiation flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/Fig3.8f_nz.png')
    #0.035

multiple_plots()
# Out:
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/3560133522.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/3560133522.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %% [markdown]
# ## Surface air temperature

# %%
TEMP_VAR = "ts_0"

#Alt 
alt_year_xr_map = get_alt_year_xr_map(
    TEMP_VAR,
    "/g/data/e14/cp3790/Charuni/ModelRun/alt-runs/um_pvera_{}.nc")  

# Con

# bundle info
bundle_1980 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1980/um_pvera_*.nc')
bundle_1999 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1999/um_pvera_*.nc')
con_bundles = {
    '1980': {
        'xr': bundle_1980,
        'start': 1981,
        'end': 1998,
    },
    '1999': {
        'xr': bundle_1999,
        'start': 2000,
        'end': 2018,
    }
}

con_year_xr_map = get_con_year_xr_map(alt_year_xr_map, con_bundles, TEMP_VAR)

# Diff
diff_year_xr_map = get_diff_year_xr_map(alt_year_xr_map, con_year_xr_map)

# %%
con_phases_xr = get_year_2phases_xr(con_year_xr_map, con_year_xr_map, phase_dim='time')
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
test = con_year_xr_map[2004]
test_shift = test.shift(longitude=1)
test_shift
# Out:
# <xarray.DataArray 'ts_0' (time: 395, latitude: 50, longitude: 110)>
# dask.array<rechunk-merge, shape=(395, 50, 110), dtype=float32, chunksize=(31, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * time       (time) datetime64[ns] 2004-06-01T12:00:00 ... 2005-06-30T12:00:00
#   * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#   * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#     height     float64 10.0

# %%
test_shift.isel(time=0).plot()

# %%
test.isel(time=0).plot()

# %%
((test - test_shift)/50).mean(dim='time').plot()

# %%
# Untested v

#year_phases_xr = get_year_phases_xr(alt_year_xr_map, diff_year_xr_map)

year_phases_xr = get_year_2phases_xr(alt_year_xr_map, diff_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
sig_da = get_sig_da(year_phases_xr)

# %%
# ensembles that show positive warming

pos1 = year_phases_xr.isel(phase=0).where(year_phases_xr.isel(phase=0)>0.05)
pos1
# Out:
# <xarray.DataArray 'ts_0' (time: 36, latitude: 50, longitude: 110)>
# dask.array<where, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#   * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#     height     float64 10.0
# Dimensions without coordinates: time

# %%
count1 = pos1.count(dim='time')
count1
# Out:
# <xarray.DataArray 'ts_0' (latitude: 50, longitude: 110)>
# dask.array<sum-aggregate, shape=(50, 110), dtype=int64, chunksize=(50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#   * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#     height     float64 10.0

# %%
count1.plot()

# %%
# representing as a proportion of all ensembles 

((count1/36)*100).plot()

# %%
(((year_phases_xr.where(year_phases_xr>0.05).count(dim='time'))/36)*100).where(mask).mean(dim='time')
# Out:
# <xarray.DataArray 'ts_0' (phase: 2, latitude: 50, longitude: 110)>
# dask.array<mean_agg-aggregate, shape=(2, 50, 110), dtype=float64, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude                (longitude) float32 135.2 135.8 ... 189.2 189.8
#   * latitude                 (latitude) float32 -52.75 -52.25 ... -28.75 -28.25
#     height                   float64 10.0
#     forecast_period          timedelta64[ns] ...
#     forecast_reference_time  datetime64[ns] ...
# Dimensions without coordinates: phase

# %%
import numpy as np

# %%
## likelihood of warming plots

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = (((year_phases_xr.where(year_phases_xr>0.05).count(dim='time'))/36)*100).where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('Purples', 10),
            vmin=0, vmax=100,
            add_colorbar=False, 
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')

        ax[col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=20)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(0, 110, 10),
                        fraction=0.035,aspect=25)
    cbar.set_label("Percentage of ensemble members", fontsize=24)  
    cbar.ax.tick_params(labelsize=20)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/thesis_fig3.5b_aus.png')
    #0.035

multiple_plots()
# Out:
# /jobfs/90141024.gadi-pbs/ipykernel_3030310/1742341758.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('Purples', 10),
# /jobfs/90141024.gadi-pbs/ipykernel_3030310/1742341758.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('Purples', 10),

# %%
## likelihood of warming plots

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = (((year_phases_xr.where(year_phases_xr>0.05).count(dim='time'))/36)*100).where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('Purples', 10),
            vmin=0, vmax=100,
            add_colorbar=False, 
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')

        ax[col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())

        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(0, 110, 10),
                        fraction=0.035,aspect=25)
    cbar.set_label("% of years showing warming", fontsize=16)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/thesis_fig3.5b_nz.png')
    #0.035

multiple_plots()
# Out:
# /jobfs/90141024.gadi-pbs/ipykernel_3030310/2096658011.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('Purples', 10),
# /jobfs/90141024.gadi-pbs/ipykernel_3030310/2096658011.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('Purples', 10),

# %%
multiple_plots_aus(year_phases_xr, sig_da, exclude_ocean=True)
# Out:
# /jobfs/90141024.gadi-pbs/ipykernel_3030310/3137433315.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 40),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90141024.gadi-pbs/ipykernel_3030310/3137433315.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 40),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %%
multiple_plots_nz(year_phases_xr, sig_da, exclude_ocean=True)
# Out:
# /jobfs/90141024.gadi-pbs/ipykernel_3030310/1552044095.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 40),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90141024.gadi-pbs/ipykernel_3030310/1552044095.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 40),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %% [markdown]
# ## Surface upward latent heat flux

# %%
TEMP_VAR = "surface_upward_latent_heat_flux"

#Alt 
alt_year_xr_map = get_alt_year_xr_map(
    TEMP_VAR,
    "/g/data/e14/cp3790/Charuni/ModelRun/alt-runs/um_pvera_{}.nc")  

# Con

# bundle info

bundle_1980 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1980/um_pvera_*.nc')
bundle_1999 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1999/um_pvera_*.nc')
con_bundles = {
    '1980': {
        'xr': bundle_1980,
        'start': 1981,
        'end': 1998,
    },
    '1999': {
        'xr': bundle_1999,
        'start': 2000,
        'end': 2018,
    }
}

con_year_xr_map = get_con_year_xr_map(alt_year_xr_map, con_bundles, TEMP_VAR)

# Diff
diff_year_xr_map = get_diff_year_xr_map(alt_year_xr_map, con_year_xr_map)

# %%
con_lh_year_month_xr = get_year_and_months_xr(con_year_xr_map, con_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
alt_lh_year_month_xr = get_year_and_months_xr(alt_year_xr_map, alt_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
diff_lh_year_month_xr = alt_lh_year_month_xr - con_lh_year_month_xr

# %%
diff_lh_year_month_sep_feb = [diff_lh_year_month_xr.isel(month=3), diff_lh_year_month_xr.isel(month=4), diff_lh_year_month_xr.isel(month=5), diff_lh_year_month_xr.isel(month=6), 
                              diff_lh_year_month_xr.isel(month=7), diff_lh_year_month_xr.isel(month=8)]
diff_lh_year_month_sep_feb
# Out:
# [<xarray.DataArray 'surface_upward_latent_heat_flux' (year: 36, latitude: 50,
#                                                       longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-09-30 1982-09-30 ... 2018-09-30
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'surface_upward_latent_heat_flux' (year: 36, latitude: 50,
#                                                       longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-10-31 1982-10-31 ... 2018-10-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'surface_upward_latent_heat_flux' (year: 36, latitude: 50,
#                                                       longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-11-30 1982-11-30 ... 2018-11-30
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'surface_upward_latent_heat_flux' (year: 36, latitude: 50,
#                                                       longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-12-31 1982-12-31 ... 2018-12-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'surface_upward_latent_heat_flux' (year: 36, latitude: 50,
#                                                       longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1982-01-31 1983-01-31 ... 2019-01-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'surface_upward_latent_heat_flux' (year: 36, latitude: 50,
#                                                       longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1982-02-28 1983-02-28 ... 2019-02-28
#  Dimensions without coordinates: year]

# %%
## new diff plot (months)

def multiple_plots():
    nrow = 2
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = diff_lh_year_month_sep_feb

    months = ['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    data_idx=0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data
            contour = cur_data[data_idx].mean(dim='year').where(mask).plot(
                ax=ax[row, col],
                cmap=plt.cm.get_cmap('bwr', 17),
                vmin=-15, vmax=15,
                add_colorbar=False,
                extend = 'both'
            )
        
            ax[row, col].contour(
                mask_mean.longitude, 
                mask_mean.latitude,
                mask_mean.values,
                levels=[0.5], 
                cmap='gray')


            ax[row, col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
            ax[row, col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
            ax[row, col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
            ax[row, col].set_title(months[data_idx], fontsize=16)
            
            data_idx += 1
            if data_idx > 5:
                stop_plotting = True
                break
        if stop_plotting:
            break

    fig.tight_layout()
    
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-15, 18, 3),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Latent heat flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)
    
    


    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/mon_Fig5a_aus.png')
    #plt.show()
    #0.035

multiple_plots()
# Out:
# /jobfs/91164646.gadi-pbs/ipykernel_789245/4204538487.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/4204538487.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/4204538487.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/4204538487.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/4204538487.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/4204538487.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),

# %%
## new diff plot (months)

def multiple_plots():
    nrow = 2
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = diff_lh_year_month_sep_feb

    months = ['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    data_idx=0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data
            contour = cur_data[data_idx].mean(dim='year').where(mask).plot(
                ax=ax[row, col],
                cmap=plt.cm.get_cmap('bwr', 17),
                vmin=-15, vmax=15,
                add_colorbar=False,
                extend = 'both'
            )
        
            ax[row, col].contour(
                mask_mean.longitude, 
                mask_mean.latitude,
                mask_mean.values,
                levels=[0.5], 
                cmap='gray')


            ax[row, col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
            ax[row, col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
            ax[row, col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())
            ax[row, col].set_title(months[data_idx], fontsize=16)
            
            data_idx += 1
            if data_idx > 5:
                stop_plotting = True
                break
        if stop_plotting:
            break

    fig.tight_layout()
    
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-15, 18, 3),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Latent heat flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)
    
    


    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/mon_Fig5a_nz.png')
    #plt.show()
    #0.035

multiple_plots()
# Out:
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2823857016.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2823857016.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2823857016.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2823857016.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2823857016.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2823857016.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),

# %%
lh_diff_xr = xr.concat([coord_to_dim(year_xr, 'event_month') for year_xr in diff_year_xr_map.values()],
                             dim="year")
lh_diff_xr
# Out:
# <xarray.DataArray 'surface_upward_latent_heat_flux' (year: 36,
#                                                      event_month_dim: 13,
#                                                      latitude: 50,
#                                                      longitude: 110)>
# dask.array<concatenate, shape=(36, 13, 50, 110), dtype=float32, chunksize=(1, 1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude    (longitude) float32 135.2 135.8 136.2 ... 188.8 189.2 189.8
#   * latitude     (latitude) float32 -52.75 -52.25 -51.75 ... -28.75 -28.25
#     height       float64 10.0
#     event_month  (year, event_month_dim) datetime64[ns] 1981-06-30 ... 2019-0...
# Dimensions without coordinates: year, event_month_dim

# %%
lh_diff_mon_xr = lh_diff_xr.mean(dim='year')
lh_diff_mon_xr
# Out:
# <xarray.DataArray 'surface_upward_latent_heat_flux' (event_month_dim: 13,
#                                                      latitude: 50,
#                                                      longitude: 110)>
# dask.array<mean_agg-aggregate, shape=(13, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#   * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#     height     float64 10.0
# Dimensions without coordinates: event_month_dim

# %%
## LHF anomalies

def multiple_plots_lhf_anom():
    nrow = 4
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = lh_diff_mon_xr
    
    month_labels = ['Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May']
    
    data_idx = 0
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data.isel(event_month_dim=data_idx)
            contour = ax[row, col].contourf(
                cur_data.longitude,
                cur_data.latitude,
                cur_data.values,
                levels=np.arange(-105, 110, 10),
                add_colorbar=False,
                cmap=plt.cm.get_cmap('bwr'),
                extend='both'
            )
            ax[row, col].coastlines()
            #ax[row, col].set_extent([135, 180, -53, -30],crs=ccrs.PlateCarree()) 
            ax[row, col].set_extent([140, 180, -50, -33],crs=ccrs.PlateCarree()) 
            
            ax[row, col].set_title(month_labels[data_idx])

            data_idx += 1
                

    # Choose the traversal you'd like: 'F' is col-wise, 'C' is row-wise           
    ax_flat = ax.flatten(order='C')

    #fig.tight_layout()              
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-100,120,20),
                        fraction=0.015,aspect=45)
    cbar.set_label(label='Latent heat flux anomaly (Wm-2)', fontsize=16)  
    cbar.ax.tick_params(labelsize=14)
    
    fig.patch.set_facecolor('white')
    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/lhf_anom_mon.png')
    plt.show()

multiple_plots_lhf_anom()

# %%
lh_year_month_xr = get_year_and_months_xr(con_year_xr_map, con_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
lh_month_xr = lh_year_month_xr.mean(dim='year')
lh_month_xr
# Out:
# <xarray.DataArray 'surface_upward_latent_heat_flux' (month: 13, latitude: 50,
#                                                      longitude: 110)>
# dask.array<mean_agg-aggregate, shape=(13, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#   * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#     height     float64 10.0
# Dimensions without coordinates: month

# %%
lh_jja = lh_month_xr.sel(month=slice(0,3)).mean(dim='month')
lh_son = lh_month_xr.sel(month=slice(3,6)).mean(dim='month')
lh_djf = lh_month_xr.sel(month=slice(6,9)).mean(dim='month')
lh_mam = lh_month_xr.sel(month=slice(9,12)).mean(dim='month')

# %%
lh_seas = xr.concat((lh_jja, lh_son, lh_djf, lh_mam), dim='time')
lh_seas
# Out:
# <xarray.DataArray 'surface_upward_latent_heat_flux' (time: 4, latitude: 50,
#                                                      longitude: 110)>
# dask.array<concatenate, shape=(4, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#   * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#     height     float64 10.0
# Dimensions without coordinates: time

# %%
#  Plot seasonal panels winds (ERA5)

def multiple_plots():
    nrow = 2
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(20,12), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data1 = lh_seas
    
    season_labels = ['JJA', 'SON', 'DJF', 'MAM']
    
    data_idx = 0
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data1[data_idx].where(mask==0).mean(dim='time')
            contour = ax[row, col].contourf(
                cur_data.longitude,
                cur_data.latitude,
                cur_data.values,
                levels=np.arange(55, 210, 10),
                add_colorbar=False,
                cmap=cmocean.cm.haline_r,
                extend='both'
           ) 
            
            ax[row, col].coastlines()
            ax[row, col].set_extent([140, 180, -50, -33],crs=ccrs.PlateCarree()) 
            ax[row, col].set_title(season_labels[data_idx], fontsize=16)
            
            data_idx += 1        
    
    #fig.tight_layout()
    plt.subplots_adjust(left=0.125,
                    bottom=0.3, 
                    right=0.5, 
                    top=0.9, 
                    wspace=0.1, 
                    hspace=0.15)
    
    cb = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(60,220,20),
                      fraction=0.035,aspect=25, extend='both') #,format='%.2f')
    cb.set_label(label='Latent heat flux (Wm-2)', size=18, weight='normal')
    cb.ax.tick_params(labelsize=14)
 
    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/lhf_seas_ocean.png')   

multiple_plots()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1714: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1714: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1714: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1714: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)

# %%
# Untested v

lh_year_phases_xr = get_year_2phases_xr(alt_year_xr_map, diff_year_xr_map)

lh_sig_da = get_sig_da(lh_year_phases_xr)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
## new diff plot (phases)

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = lh_year_phases_xr.mean(dim='time').where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('bwr', 31),
            vmin=-15, vmax=15,
            add_colorbar=False,
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')
        
        phase_mask_mean = lh_sig_da[col].where(mask).mean(dim='time')
        ax[col].contourf(
            phase_mask_mean.longitude,
            phase_mask_mean.latitude,
            phase_mask_mean.values,
            levels=[0.00, 0.05, 1.00],
            hatches=['.', None],
            colors='none',
            add_colorbar=False,
        )

        ax[col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-15, 16, 3),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Latent heat flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/Fig3.10a_aus.jpg')
    #0.035

multiple_plots()
# Out:
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/2474541159.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 31),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/2474541159.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 31),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %%
## new diff plot (phases)

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = lh_year_phases_xr.mean(dim='time').where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('bwr', 31),
            vmin=-15, vmax=15,
            add_colorbar=False,
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')
        
        phase_mask_mean = lh_sig_da[col].where(mask).mean(dim='time')
        ax[col].contourf(
            phase_mask_mean.longitude,
            phase_mask_mean.latitude,
            phase_mask_mean.values,
            levels=[0.00, 0.05, 1.00],
            hatches=['.', None],
            colors='none',
            add_colorbar=False,
        )

        ax[col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-15, 16, 3),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Latent heat flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/Fig3.10b_nz.jpg')
    #0.035

multiple_plots()
# Out:
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/559145636.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 31),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/559145636.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 31),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %% [markdown]
# ## Sensible heat flux

# %%
TEMP_VAR = "hfss"

#Alt 
alt_year_xr_map = get_alt_year_xr_map(
    TEMP_VAR,
    "/g/data/e14/cp3790/Charuni/ModelRun/alt-runs/um_pvera_{}.nc")  

# Con

# bundle info
bundle_1980 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1980/um_pvera_*.nc')
bundle_1999 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1999/um_pvera_*.nc')
con_bundles = {
    '1980': {
        'xr': bundle_1980,
        'start': 1981,
        'end': 1998,
    },
    '1999': {
        'xr': bundle_1999,
        'start': 2000,
        'end': 2018,
    }
}

con_year_xr_map = get_con_year_xr_map(alt_year_xr_map, con_bundles, TEMP_VAR)

# Diff
diff_year_xr_map = get_diff_year_xr_map(alt_year_xr_map, con_year_xr_map)

# %%
con_sh_year_month_xr = get_year_and_months_xr(con_year_xr_map, con_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
alt_sh_year_month_xr = get_year_and_months_xr(alt_year_xr_map, alt_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
diff_sh_year_month_xr = alt_sh_year_month_xr - con_sh_year_month_xr

# %%
diff_sh_year_month_sep_feb = [diff_sh_year_month_xr.isel(month=3), diff_sh_year_month_xr.isel(month=4), diff_sh_year_month_xr.isel(month=5), diff_sh_year_month_xr.isel(month=6), 
                              diff_sh_year_month_xr.isel(month=7), diff_sh_year_month_xr.isel(month=8)]
diff_sh_year_month_sep_feb
# Out:
# [<xarray.DataArray 'hfss' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-09-30 1982-09-30 ... 2018-09-30
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'hfss' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-10-31 1982-10-31 ... 2018-10-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'hfss' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-11-30 1982-11-30 ... 2018-11-30
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'hfss' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-12-31 1982-12-31 ... 2018-12-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'hfss' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1982-01-31 1983-01-31 ... 2019-01-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'hfss' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1982-02-28 1983-02-28 ... 2019-02-28
#  Dimensions without coordinates: year]

# %%
## new diff plot (months)

def multiple_plots():
    nrow = 2
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = diff_sh_year_month_sep_feb

    months = ['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    data_idx=0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data
            contour = cur_data[data_idx].mean(dim='year').where(mask).plot(
                ax=ax[row, col],
                cmap=plt.cm.get_cmap('bwr', 17),
                vmin=-15, vmax=15,
                add_colorbar=False,
                extend = 'both'
            )
        
            ax[row, col].contour(
                mask_mean.longitude, 
                mask_mean.latitude,
                mask_mean.values,
                levels=[0.5], 
                cmap='gray')


            ax[row, col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
            ax[row, col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
            ax[row, col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
            ax[row, col].set_title(months[data_idx], fontsize=16)
            
            data_idx += 1
            if data_idx > 5:
                stop_plotting = True
                break
        if stop_plotting:
            break

    fig.tight_layout()
    
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-15, 18, 3),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Sensible heat flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)
    
    


    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/mon_Fig5b_aus.png')
    #plt.show()
    #0.035

multiple_plots()
# Out:
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2446226950.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2446226950.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2446226950.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2446226950.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2446226950.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2446226950.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),

# %%
## new diff plot (months)

def multiple_plots():
    nrow = 2
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = diff_sh_year_month_sep_feb

    months = ['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    data_idx=0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data
            contour = cur_data[data_idx].mean(dim='year').where(mask).plot(
                ax=ax[row, col],
                cmap=plt.cm.get_cmap('bwr', 17),
                vmin=-15, vmax=15,
                add_colorbar=False,
                extend = 'both'
            )
        
            ax[row, col].contour(
                mask_mean.longitude, 
                mask_mean.latitude,
                mask_mean.values,
                levels=[0.5], 
                cmap='gray')


            ax[row, col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
            ax[row, col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
            ax[row, col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())
            ax[row, col].set_title(months[data_idx], fontsize=16)
            
            data_idx += 1
            if data_idx > 5:
                stop_plotting = True
                break
        if stop_plotting:
            break

    fig.tight_layout()
    
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-15, 18, 3),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Sensible heat flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)
    
    


    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/mon_Fig5b_nz.png')
    #plt.show()
    #0.035

multiple_plots()
# Out:
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2442273970.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2442273970.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2442273970.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2442273970.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2442273970.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2442273970.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),

# %%
sh_diff_xr = xr.concat([coord_to_dim(year_xr, 'event_month') for year_xr in diff_year_xr_map.values()],
                            dim="year")
sh_diff_xr
# Out:
# <xarray.DataArray 'hfss' (year: 36, event_month_dim: 13, latitude: 50,
#                           longitude: 110)>
# dask.array<concatenate, shape=(36, 13, 50, 110), dtype=float32, chunksize=(1, 1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#     event_month  (year, event_month_dim) datetime64[ns] 1981-06-30 ... 2019-0...
#   * longitude    (longitude) float32 135.2 135.8 136.2 ... 188.8 189.2 189.8
#   * latitude     (latitude) float32 -52.75 -52.25 -51.75 ... -28.75 -28.25
#     height       float64 10.0
# Dimensions without coordinates: year, event_month_dim

# %%
sh_diff_mon_xr = sh_diff_xr.mean(dim='year')
sh_diff_mon_xr
# Out:
# <xarray.DataArray 'hfss' (event_month_dim: 13, latitude: 50, longitude: 110)>
# dask.array<mean_agg-aggregate, shape=(13, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#   * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#     height     float64 10.0
# Dimensions without coordinates: event_month_dim

# %%
## SHF anomalies

def multiple_plots_shf_anom():
    nrow = 4
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = sh_diff_mon_xr
    
    month_labels = ['Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May']
    
    data_idx = 0
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data.isel(event_month_dim=data_idx)
            contour = ax[row, col].contourf(
                cur_data.longitude,
                cur_data.latitude,
                cur_data.values,
                levels=np.arange(-32.5, 35, 5),
                add_colorbar=False,
                cmap=plt.cm.get_cmap('bwr', 13),
                extend='both'
            )
            ax[row, col].coastlines()
            #ax[row, col].set_extent([135, 180, -53, -30],crs=ccrs.PlateCarree()) 
            ax[row, col].set_extent([140, 180, -50, -33],crs=ccrs.PlateCarree()) 
            
            ax[row, col].set_title(month_labels[data_idx])

            data_idx += 1
                

    # Choose the traversal you'd like: 'F' is col-wise, 'C' is row-wise           
    ax_flat = ax.flatten(order='C')

    #fig.tight_layout()              
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-30,40,10),
                        fraction=0.015,aspect=45)
    cbar.set_label(label='Sensible heat flux anomaly (Wm-2)', fontsize=16)  
    cbar.ax.tick_params(labelsize=14)
    
    fig.patch.set_facecolor('white')
    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/shf_anom_mon.png')
    plt.show()

multiple_plots_shf_anom()

# %%
sh_year_month_xr = get_year_and_months_xr(con_year_xr_map, con_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
sh_month_xr = sh_year_month_xr.mean(dim='year')
sh_month_xr
# Out:
# <xarray.DataArray 'hfss' (month: 13, latitude: 50, longitude: 110)>
# dask.array<mean_agg-aggregate, shape=(13, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#   * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#     height     float64 10.0
# Dimensions without coordinates: month

# %%
#  Plot monthly panels winds (ERA5)

def multiple_plots():
    nrow = 3
    ncol = 4
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(20,12), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data1 = sh_month_xr.where((mask==0).mean(dim='time'))
    
    month_labels = ['Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May']
    
    data_idx = 0
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data1[data_idx]
            contour = ax[row, col].contourf(
                cur_data.longitude,
                cur_data.latitude,
                cur_data.values,
                levels=np.arange(7.5, 45, 5),
                add_colorbar=False,
                cmap=cmocean.cm.haline_r,
                extend='both'
           ) 
            
            ax[row, col].coastlines()
            ax[row, col].set_extent([140, 180, -50, -33],crs=ccrs.PlateCarree()) 
            ax[row, col].set_title(month_labels[data_idx], fontsize=16)
            
            data_idx += 1        
    
    cb = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(10,50,10),
                      fraction=0.035,aspect=25, extend='both') #,format='%.2f')
    cb.set_label(label='Sensible heat flux (Wm-2)', size=18, weight='normal')
    cb.ax.tick_params(labelsize=14)
 
    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/shf_mon_ocean.png')   

multiple_plots()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1714: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)

# %%
sh_jja = sh_month_xr.sel(month=slice(0,3)).mean(dim='month')
sh_son = sh_month_xr.sel(month=slice(3,6)).mean(dim='month')
sh_djf = sh_month_xr.sel(month=slice(6,9)).mean(dim='month')
sh_mam = sh_month_xr.sel(month=slice(9,12)).mean(dim='month')

# %%
sh_seas = xr.concat((sh_jja, sh_son, sh_djf, sh_mam), dim='time')
sh_seas
# Out:
# <xarray.DataArray 'hfss' (time: 4, latitude: 50, longitude: 110)>
# dask.array<concatenate, shape=(4, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#   * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#     height     float64 10.0
# Dimensions without coordinates: time

# %%
#  Plot seasonal panels winds (ERA5)

def multiple_plots():
    nrow = 2
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(20,12), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data1 = sh_seas.where((mask==0).mean(dim='time'))
    
    season_labels = ['JJA', 'SON', 'DJF', 'MAM']
    
    data_idx = 0
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data1[data_idx]
            contour = ax[row, col].contourf(
                cur_data.longitude,
                cur_data.latitude,
                cur_data.values,
                levels=np.arange(7.5, 45, 5),
                add_colorbar=False,
                cmap=cmocean.cm.haline_r,
                extend='both'
           ) 
            
            ax[row, col].coastlines()
            ax[row, col].set_extent([140, 180, -50, -33],crs=ccrs.PlateCarree()) 
            ax[row, col].set_title(season_labels[data_idx], fontsize=16)
            
            data_idx += 1        
    
    #fig.tight_layout()
    plt.subplots_adjust(left=0.125,
                    bottom=0.3, 
                    right=0.5, 
                    top=0.9, 
                    wspace=0.1, 
                    hspace=0.15)
    
    cb = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(10,50,10),
                      fraction=0.035,aspect=25, extend='both') #,format='%.2f')
    cb.set_label(label='Sensible heat flux (Wm-2)', size=18, weight='normal')
    cb.ax.tick_params(labelsize=14)
 
    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/shf_seas_ocean.png')   

multiple_plots()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1714: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)

# %%
# Untested v

sh_year_phases_xr = get_year_2phases_xr(alt_year_xr_map, diff_year_xr_map)

sh_sig_da = get_sig_da(sh_year_phases_xr)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
## new diff plot (phases)

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = sh_year_phases_xr.mean(dim='time').where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('bwr', 31),
            vmin=-15, vmax=15,
            add_colorbar=False, 
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')
        
        phase_mask_mean = sh_sig_da[col].where(mask).mean(dim='time')
        ax[col].contourf(
            phase_mask_mean.longitude,
            phase_mask_mean.latitude,
            phase_mask_mean.values,
            levels=[0.00, 0.05, 1.00],
            hatches=['.', None],
            colors='none',
            add_colorbar=False,
        )

        ax[col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-15, 16, 3),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Sensible heat flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/Fig3.10b_aus.jpg')
    #0.035

multiple_plots()
# Out:
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/1445887431.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 31),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/1445887431.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 31),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %%
## new diff plot (phases)

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = sh_year_phases_xr.mean(dim='time').where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('bwr', 31),
            vmin=-15, vmax=15,
            add_colorbar=False, 
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')
        
        phase_mask_mean = sh_sig_da[col].where(mask).mean(dim='time')
        ax[col].contourf(
            phase_mask_mean.longitude,
            phase_mask_mean.latitude,
            phase_mask_mean.values,
            levels=[0.00, 0.05, 1.00],
            hatches=['.', None],
            colors='none',
            add_colorbar=False,
        )

        ax[col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-15, 16, 3),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Sensible heat flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/Fig3.10b_nz.jpg')
    #0.035

multiple_plots()
# Out:
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/430415119.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 31),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/430415119.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 31),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %% [markdown]
# ## Shortwave radiation flux

# %%
TEMP_VAR = "rss_corr"

#Alt 
alt_year_xr_map = get_alt_year_xr_map(
    TEMP_VAR,
    "/g/data/e14/cp3790/Charuni/ModelRun/alt-runs/um_pvera_{}.nc")  

# Con

# bundle info
bundle_1980 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1980/um_pvera_*.nc')
bundle_1999 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1999/um_pvera_*.nc')
con_bundles = {
    '1980': {
        'xr': bundle_1980,
        'start': 1981,
        'end': 1998,
    },
    '1999': {
        'xr': bundle_1999,
        'start': 2000,
        'end': 2018,
    }
}

con_year_xr_map = get_con_year_xr_map(alt_year_xr_map, con_bundles, TEMP_VAR)

# Diff
diff_year_xr_map = get_diff_year_xr_map(alt_year_xr_map, con_year_xr_map)

# %%
con_sw_year_month_xr = get_year_and_months_xr(con_year_xr_map, con_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
alt_sw_year_month_xr = get_year_and_months_xr(alt_year_xr_map, alt_year_xr_map)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
diff_sw_year_month_xr = alt_sw_year_month_xr - con_sw_year_month_xr

# %%
diff_sw_year_month_sep_feb = [diff_sw_year_month_xr.isel(month=3), diff_sw_year_month_xr.isel(month=4), diff_sw_year_month_xr.isel(month=5), diff_sw_year_month_xr.isel(month=6), 
                              diff_sw_year_month_xr.isel(month=7), diff_sw_year_month_xr.isel(month=8)]
diff_sw_year_month_sep_feb
# Out:
# [<xarray.DataArray 'rss_corr' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-09-30 1982-09-30 ... 2018-09-30
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'rss_corr' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-10-31 1982-10-31 ... 2018-10-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'rss_corr' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-11-30 1982-11-30 ... 2018-11-30
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'rss_corr' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-12-31 1982-12-31 ... 2018-12-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'rss_corr' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1982-01-31 1983-01-31 ... 2019-01-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray 'rss_corr' (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1982-02-28 1983-02-28 ... 2019-02-28
#  Dimensions without coordinates: year]

# %%
## new diff plot (months)

def multiple_plots():
    nrow = 2
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = diff_sw_year_month_sep_feb

    months = ['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    data_idx=0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data
            contour = cur_data[data_idx].mean(dim='year').where(mask).plot(
                ax=ax[row, col],
                cmap=plt.cm.get_cmap('bwr', 17),
                vmin=-8, vmax=8,
                add_colorbar=False,
                extend = 'both'
            )
        
            ax[row, col].contour(
                mask_mean.longitude, 
                mask_mean.latitude,
                mask_mean.values,
                levels=[0.5], 
                cmap='gray')


            ax[row, col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
            ax[row, col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
            ax[row, col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
            ax[row, col].set_title(months[data_idx], fontsize=16)
            
            data_idx += 1
            if data_idx > 5:
                stop_plotting = True
                break
        if stop_plotting:
            break

    fig.tight_layout()
    
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down SW flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)
    
    


    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/mon_Fig4b_aus.png')
    #plt.show()
    #0.035

multiple_plots()
# Out:
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2647417585.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2647417585.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2647417585.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2647417585.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2647417585.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2647417585.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),

# %%
## new diff plot (months)

def multiple_plots():
    nrow = 2
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = diff_sw_year_month_sep_feb

    months = ['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    data_idx=0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data
            contour = cur_data[data_idx].mean(dim='year').where(mask).plot(
                ax=ax[row, col],
                cmap=plt.cm.get_cmap('bwr', 17),
                vmin=-8, vmax=8,
                add_colorbar=False,
                extend = 'both'
            )
        
            ax[row, col].contour(
                mask_mean.longitude, 
                mask_mean.latitude,
                mask_mean.values,
                levels=[0.5], 
                cmap='gray')


            ax[row, col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
            ax[row, col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
            ax[row, col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())
            ax[row, col].set_title(months[data_idx], fontsize=16)
            
            data_idx += 1
            if data_idx > 5:
                stop_plotting = True
                break
        if stop_plotting:
            break

    fig.tight_layout()
    
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down SW flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)
    
    


    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/mon_Fig4b_nz.png')
    #plt.show()
    #0.035

multiple_plots()
# Out:
# /jobfs/91164646.gadi-pbs/ipykernel_789245/84849145.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/84849145.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/84849145.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/84849145.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/84849145.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/84849145.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),

# %%
sw_year_month_xr = get_year_and_months_xr(con_year_xr_map, con_year_xr_map)
sw_month_xr = sw_year_month_xr.mean(dim='year')
sw_jja = sw_month_xr.sel(month=slice(0,3)).mean(dim='month')
sw_son = sw_month_xr.sel(month=slice(3,6)).mean(dim='month')
sw_djf = sw_month_xr.sel(month=slice(6,9)).mean(dim='month')
sw_mam = sw_month_xr.sel(month=slice(9,12)).mean(dim='month')
sw_seas = xr.concat((sw_jja, sw_son, sw_djf, sw_mam), dim='time')
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/numpy/core/_methods.py:179: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
#  Plot seasonal panels 

def multiple_plots():
    nrow = 2
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(20,12), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data1 = sw_seas.where((mask==0).mean(dim='time'))
    
    season_labels = ['JJA', 'SON', 'DJF', 'MAM']
    
    data_idx = 0
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data1[data_idx]
            contour = ax[row, col].contourf(
                cur_data.longitude,
                cur_data.latitude,
                cur_data.values,
                levels=np.arange(95, 210, 10),
                add_colorbar=False,
                cmap=cmocean.cm.solar_r,
                extend='both'
           ) 
            
            ax[row, col].coastlines()
            ax[row, col].set_extent([140, 180, -50, -33],crs=ccrs.PlateCarree()) 
            ax[row, col].set_title(season_labels[data_idx], fontsize=16)
            
            data_idx += 1        
    
    #fig.tight_layout()
    plt.subplots_adjust(left=0.125,
                    bottom=0.3, 
                    right=0.5, 
                    top=0.9, 
                    wspace=0.1, 
                    hspace=0.15)
    
    cb = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(100,210,10),
                      fraction=0.035,aspect=25, extend='both') #,format='%.2f')
    cb.set_label(label='Net down shortwave radiation (Wm-2)', size=18, weight='normal')
    cb.ax.tick_params(labelsize=14)
 
    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/sw_seas_ocean.png')   

multiple_plots()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1714: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)

# %%
# Untested v

sw_year_phases_xr = get_year_2phases_xr(alt_year_xr_map, diff_year_xr_map)

sw_sig_da = get_sig_da(sw_year_phases_xr)
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
## new diff plot (phases)

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = sw_year_phases_xr.mean(dim='time').where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('bwr', 17),
            vmin=-8, vmax=8,
            add_colorbar=False,
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')
        
        phase_mask_mean = sw_sig_da[col].where(mask).mean(dim='time')
        ax[col].contourf(
            phase_mask_mean.longitude,
            phase_mask_mean.latitude,
            phase_mask_mean.values,
            levels=[0.00, 0.05, 1.00],
            hatches=['.', None],
            colors='none',
            add_colorbar=False,
        )

        ax[col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down surface shortwave flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/Fig3.8c_aus.png')
    #0.035

multiple_plots()
# Out:
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/3613552341.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/3613552341.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %%
## new diff plot (phases)

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = sw_year_phases_xr.mean(dim='time').where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('bwr', 21),
            vmin=-8, vmax=8,
            add_colorbar=False,
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')
        
        phase_mask_mean = sw_sig_da[col].where(mask).mean(dim='time')
        ax[col].contourf(
            phase_mask_mean.longitude,
            phase_mask_mean.latitude,
            phase_mask_mean.values,
            levels=[0.00, 0.05, 1.00],
            hatches=['.', None],
            colors='none',
            add_colorbar=False,
        )

        ax[col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down SW flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/Fig3.6d_nz.png')
    #0.035

multiple_plots()
# Out:
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/2635346335.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 21),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/2635346335.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 21),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %% [markdown]
# ## Net SW + Net LW

# %%
diff_total_sw_lw = diff_sw_year_month_xr + diff_lw_year_month_xr

# %%
diff_total_sw_lw_sep_feb = [diff_total_sw_lw.isel(month=3), diff_total_sw_lw.isel(month=4), diff_total_sw_lw.isel(month=5), diff_total_sw_lw.isel(month=6), 
                              diff_total_sw_lw.isel(month=7), diff_total_sw_lw.isel(month=8)]
diff_total_sw_lw_sep_feb
# Out:
# [<xarray.DataArray (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-09-30 1982-09-30 ... 2018-09-30
#  Dimensions without coordinates: year,
#  <xarray.DataArray (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-10-31 1982-10-31 ... 2018-10-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-11-30 1982-11-30 ... 2018-11-30
#  Dimensions without coordinates: year,
#  <xarray.DataArray (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1981-12-31 1982-12-31 ... 2018-12-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1982-01-31 1983-01-31 ... 2019-01-31
#  Dimensions without coordinates: year,
#  <xarray.DataArray (year: 36, latitude: 50, longitude: 110)>
#  dask.array<getitem, shape=(36, 50, 110), dtype=float32, chunksize=(1, 50, 110), chunktype=numpy.ndarray>
#  Coordinates:
#    * longitude  (longitude) float32 135.2 135.8 136.2 136.8 ... 188.8 189.2 189.8
#    * latitude   (latitude) float32 -52.75 -52.25 -51.75 ... -29.25 -28.75 -28.25
#      height     float64 10.0
#      time       (year) datetime64[ns] 1982-02-28 1983-02-28 ... 2019-02-28
#  Dimensions without coordinates: year]

# %%
## new diff plot (months)

def multiple_plots():
    nrow = 2
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = diff_total_sw_lw_sep_feb

    months = ['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    data_idx=0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data
            contour = cur_data[data_idx].mean(dim='year').where(mask).plot(
                ax=ax[row, col],
                cmap=plt.cm.get_cmap('bwr', 17),
                vmin=-8, vmax=8,
                add_colorbar=False,
                extend = 'both'
            )
        
            ax[row, col].contour(
                mask_mean.longitude, 
                mask_mean.latitude,
                mask_mean.values,
                levels=[0.5], 
                cmap='gray')


            ax[row, col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
            ax[row, col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
            ax[row, col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
            ax[row, col].set_title(months[data_idx], fontsize=16)
            
            data_idx += 1
            if data_idx > 5:
                stop_plotting = True
                break
        if stop_plotting:
            break

    fig.tight_layout()
    
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down SW and LW flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)
    
    


    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/mon_Fig4a_aus.png')
    #plt.show()
    #0.035

multiple_plots()
# Out:
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1100265432.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1100265432.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1100265432.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1100265432.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1100265432.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/1100265432.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),

# %%
## new diff plot (months)

def multiple_plots():
    nrow = 2
    ncol = 3
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = diff_total_sw_lw_sep_feb

    months = ['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    data_idx=0
    stop_plotting = False
    for row in range(nrow):
        for col in range(ncol):
            cur_data = data
            contour = cur_data[data_idx].mean(dim='year').where(mask).plot(
                ax=ax[row, col],
                cmap=plt.cm.get_cmap('bwr', 17),
                vmin=-8, vmax=8,
                add_colorbar=False,
                extend = 'both'
            )
        
            ax[row, col].contour(
                mask_mean.longitude, 
                mask_mean.latitude,
                mask_mean.values,
                levels=[0.5], 
                cmap='gray')


            ax[row, col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
            ax[row, col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
            ax[row, col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())
            ax[row, col].set_title(months[data_idx], fontsize=16)
            
            data_idx += 1
            if data_idx > 5:
                stop_plotting = True
                break
        if stop_plotting:
            break

    fig.tight_layout()
    
    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down SW and LW flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)
    
    


    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/mon_Fig4s_nz.png')
    #plt.show()
    #0.035

multiple_plots()
# Out:
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2735146587.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2735146587.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2735146587.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2735146587.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2735146587.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /jobfs/91164646.gadi-pbs/ipykernel_789245/2735146587.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),

# %%
total = sw_year_phases_xr + lw_year_phases_xr

# %%
total_sig = sw_sig_da + lw_sig_da

# %%
total.isel(phase=0).mean(dim='time').plot()

# %%
## new diff plot (phases)

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = total.mean(dim='time').where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('bwr', 17),
            vmin=-8, vmax=8,
            add_colorbar=False,
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')
        
        phase_mask_mean = total_sig[col].where(mask).mean(dim='time')
        ax[col].contourf(
            phase_mask_mean.longitude,
            phase_mask_mean.latitude,
            phase_mask_mean.values,
            levels=[0.00, 0.05, 1.00],
            hatches=['.', None],
            colors='none',
            add_colorbar=False,
        )

        ax[col].set_extent([140, 155, -48, -33],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([140, 145, 150, 155],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-48, -45, -40, -35, -33],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down SW and LW flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/Fig3.6a_aus.png')
    #0.035

multiple_plots()
# Out:
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/2599961005.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/2599961005.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)

# %%
## new diff plot (phases)

def multiple_plots():
    nrow = 1
    ncol = 2
    
    fig, ax = plt.subplots(nrows=nrow,ncols=ncol, figsize=(16,9), 
            subplot_kw={'projection': ccrs.PlateCarree()}) # Specifies the projection for the plots    
    
    data = total.mean(dim='time').where(mask).mean(dim='time')

    phases = ['Sep-Feb', 'March-June']
    contour = None
    mask_mean = mask.mean(dim='time')
    
    for col in range(ncol):
        cur_data = data[col]
        contour = cur_data.plot(
            ax=ax[col],
            cmap=plt.cm.get_cmap('bwr', 17),
            vmin=-8, vmax=8,
            add_colorbar=False,
        )
        
        ax[col].contour(
            mask_mean.longitude, 
            mask_mean.latitude,
            mask_mean.values,
            levels=[0.5], 
            cmap='gray')
        
        phase_mask_mean = sw_sig_da[col].where(mask).mean(dim='time')
        ax[col].contourf(
            phase_mask_mean.longitude,
            phase_mask_mean.latitude,
            phase_mask_mean.values,
            levels=[0.00, 0.05, 1.00],
            hatches=['.', None],
            colors='none',
            add_colorbar=False,
        )

        ax[col].set_extent([165, 180, -49, -34],crs=ccrs.PlateCarree()) 
        ax[col].set_xticks([165, 170, 175, 180],crs=ccrs.PlateCarree())
        ax[col].set_yticks([-49, -45, -40, -34],crs=ccrs.PlateCarree())
        ax[col].set_title(phases[col], fontsize=16)

    cbar = fig.colorbar(contour, ax=ax.ravel().tolist(), orientation="horizontal",ticks=np.arange(-8, 9, 1),
                        fraction=0.035,aspect=25, extend='both')
    cbar.set_label("Net down SW and LW flux anomaly (Wm-2)", fontsize=18)  
    cbar.ax.tick_params(labelsize=14)

    plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Revisions/Fig3.6b_nz.png')
    #0.035

multiple_plots()
# Out:
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/2860006633.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
# /jobfs/90503830.gadi-pbs/ipykernel_1895348/2860006633.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('bwr', 17),
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1662: UserWarning: The following kwargs were not used by contour: 'add_colorbar'
#   result = super().contourf(*args, **kwargs)
