# %%
# %run model-run-function-definitions.ipynb
import math

# %% [markdown]
# ## Surface air temperature

# %%
TEMP_VAR = "ts_0"

#Alt 
alt_year_temp_xr_map = get_alt_year_xr_map(
    TEMP_VAR,
    "/g/data/e14/cp3790/Charuni/ModelRun/alt-runs/um_pvera_{}.nc")  

# Con

# bundle info
bundle_1980 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1980/um_pvera_*.nc')
bundle_1999 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1999/um_pvera_*.nc')
con_bundles = {
    '1980': {
        'xr': bundle_1980,
        'start': 1981,
        'end': 1998,
    },
    '1999': {
        'xr': bundle_1999,
        'start': 2000,
        'end': 2018,
    }
}

con_year_temp_xr_map = get_con_year_xr_map(alt_year_temp_xr_map, con_bundles, TEMP_VAR)

# Diff
diff_year_temp_xr_map = get_diff_year_xr_map(alt_year_temp_xr_map, con_year_temp_xr_map)

# %% [markdown]
# ## U wind

# %%
TEMP_VAR = "uas"

#Alt 
alt_year_xr_map = get_alt_year_xr_map(
    TEMP_VAR,
    "/g/data/e14/cp3790/Charuni/ModelRun/alt-runs/um_pvera_{}.nc")  

# Con

# bundle info
bundle_1980 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1980/um_pvera_*.nc')
bundle_1999 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1999/um_pvera_*.nc')
con_bundles = {
    '1980': {
        'xr': bundle_1980,
        'start': 1981,
        'end': 1998,
    },
    '1999': {
        'xr': bundle_1999,
        'start': 2000,
        'end': 2018,
    }
}

con_year_uas_xr_map = get_con_year_xr_map(alt_year_xr_map, con_bundles, TEMP_VAR)

# Diff
diff_year_uas_xr_map = get_diff_year_xr_map(alt_year_xr_map, con_year_uas_xr_map)

# %% [markdown]
# ## V wind

# %%
TEMP_VAR = "vas"

#Alt 
alt_year_xr_map = get_alt_year_xr_map(
    TEMP_VAR,
    "/g/data/e14/cp3790/Charuni/ModelRun/alt-runs/um_pvera_{}.nc")  

# Con

# bundle info
bundle_1980 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1980/um_pvera_*.nc')
bundle_1999 = xr.open_mfdataset('/g/data/e14/cp3790/Charuni/ModelRun/control-new/result-uby108-1999/um_pvera_*.nc')
con_bundles = {
    '1980': {
        'xr': bundle_1980,
        'start': 1981,
        'end': 1998,
    },
    '1999': {
        'xr': bundle_1999,
        'start': 2000,
        'end': 2018,
    }
}

con_year_vas_xr_map = get_con_year_xr_map(alt_year_xr_map, con_bundles, TEMP_VAR)

# Diff
diff_year_vas_xr_map = get_diff_year_xr_map(alt_year_xr_map, con_year_vas_xr_map)

# %% [markdown]
# ## Variables xarray from maps

# %%
con_phases_temp_xr = get_year_2phases_xr(con_year_temp_xr_map, con_year_temp_xr_map, phase_dim='time')
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
diff_phases_temp_xr = get_year_2phases_xr(diff_year_temp_xr_map, diff_year_temp_xr_map, phase_dim='event_month')
# Out:
# Checking coords of 1981 - has 'longtitude'
# Checking coords of 1982 - has 'longtitude'
# Checking coords of 1983 - has 'longtitude'
# Checking coords of 1984 - has 'longtitude'
# Checking coords of 1985 - has 'longtitude'
# Checking coords of 1986 - has 'longtitude'
# Checking coords of 1987 - has 'longtitude'
# Checking coords of 1988 - has 'longtitude'
# Checking coords of 1989 - has 'longtitude'
# Checking coords of 1990 - has 'longtitude'
# Checking coords of 1991 - has 'longtitude'
# Checking coords of 1992 - has 'longtitude'
# Checking coords of 1993 - has 'longtitude'
# Checking coords of 1994 - has 'longtitude'
# Checking coords of 1996 - has 'longtitude'
# Checking coords of 1997 - has 'longtitude'
# Checking coords of 1998 - has 'longtitude'
# Checking coords of 2000 - has 'longtitude'
# Checking coords of 2001 - has 'longtitude'
# Checking coords of 2002 - has 'longtitude'
# Checking coords of 2003 - has 'longtitude'
# Checking coords of 2004 - has 'longtitude'
# Checking coords of 2005 - has 'longtitude'
# Checking coords of 2006 - has 'longtitude'
# Checking coords of 2007 - has 'longtitude'
# Checking coords of 2008 - has 'longtitude'
# Checking coords of 2009 - has 'longtitude'
# Checking coords of 2010 - has 'longtitude'
# Checking coords of 2011 - has 'longtitude'
# Checking coords of 2012 - has 'longtitude'
# Checking coords of 2013 - has 'longtitude'
# Checking coords of 2014 - has 'longtitude'
# Checking coords of 2015 - has 'longtitude'
# Checking coords of 2016 - has 'longtitude'
# Checking coords of 2017 - has 'longtitude'
# Checking coords of 2018 - has 'longtitude'

# %%
con_phases_uas_xr = get_year_2phases_xr(con_year_uas_xr_map, con_year_uas_xr_map, phase_dim='time')
# Out:
# Checking coords of 1981 - has 'longitude_0' -> renaming coords...
# Checking coords of 1982 - has 'longitude_0' -> renaming coords...
# Checking coords of 1983 - has 'longitude_0' -> renaming coords...
# Checking coords of 1984 - has 'longitude_0' -> renaming coords...
# Checking coords of 1985 - has 'longitude_0' -> renaming coords...
# Checking coords of 1986 - has 'longitude_0' -> renaming coords...
# Checking coords of 1987 - has 'longitude_0' -> renaming coords...
# Checking coords of 1988 - has 'longitude_0' -> renaming coords...
# Checking coords of 1989 - has 'longitude_0' -> renaming coords...
# Checking coords of 1990 - has 'longitude_0' -> renaming coords...
# Checking coords of 1991 - has 'longitude_0' -> renaming coords...
# Checking coords of 1992 - has 'longitude_0' -> renaming coords...
# Checking coords of 1993 - has 'longitude_0' -> renaming coords...
# Checking coords of 1994 - has 'longitude_0' -> renaming coords...
# Checking coords of 1996 - has 'longitude_0' -> renaming coords...
# Checking coords of 1997 - has 'longitude_0' -> renaming coords...
# Checking coords of 1998 - has 'longitude_0' -> renaming coords...
# Checking coords of 2000 - has 'longitude_0' -> renaming coords...
# Checking coords of 2001 - has 'longitude_0' -> renaming coords...
# Checking coords of 2002 - has 'longitude_0' -> renaming coords...
# Checking coords of 2003 - has 'longitude_0' -> renaming coords...
# Checking coords of 2004 - has 'longitude_0' -> renaming coords...
# Checking coords of 2005 - has 'longitude_0' -> renaming coords...
# Checking coords of 2006 - has 'longitude_0' -> renaming coords...
# Checking coords of 2007 - has 'longitude_0' -> renaming coords...
# Checking coords of 2008 - has 'longitude_0' -> renaming coords...
# Checking coords of 2009 - has 'longitude_0' -> renaming coords...
# Checking coords of 2010 - has 'longitude_0' -> renaming coords...
# Checking coords of 2011 - has 'longitude_0' -> renaming coords...
# Checking coords of 2012 - has 'longitude_0' -> renaming coords...
# Checking coords of 2013 - has 'longitude_0' -> renaming coords...
# Checking coords of 2014 - has 'longitude_0' -> renaming coords...
# Checking coords of 2015 - has 'longitude_0' -> renaming coords...
# Checking coords of 2016 - has 'longitude_0' -> renaming coords...
# Checking coords of 2017 - has 'longitude_0' -> renaming coords...
# Checking coords of 2018 - has 'longitude_0' -> renaming coords...

# %%
diff_phases_uas_xr = get_year_2phases_xr(diff_year_uas_xr_map, diff_year_uas_xr_map, phase_dim='event_month')
# Out:
# Checking coords of 1981 - has 'longitude_0' -> renaming coords...
# Checking coords of 1982 - has 'longitude_0' -> renaming coords...
# Checking coords of 1983 - has 'longitude_0' -> renaming coords...
# Checking coords of 1984 - has 'longitude_0' -> renaming coords...
# Checking coords of 1985 - has 'longitude_0' -> renaming coords...
# Checking coords of 1986 - has 'longitude_0' -> renaming coords...
# Checking coords of 1987 - has 'longitude_0' -> renaming coords...
# Checking coords of 1988 - has 'longitude_0' -> renaming coords...
# Checking coords of 1989 - has 'longitude_0' -> renaming coords...
# Checking coords of 1990 - has 'longitude_0' -> renaming coords...
# Checking coords of 1991 - has 'longitude_0' -> renaming coords...
# Checking coords of 1992 - has 'longitude_0' -> renaming coords...
# Checking coords of 1993 - has 'longitude_0' -> renaming coords...
# Checking coords of 1994 - has 'longitude_0' -> renaming coords...
# Checking coords of 1996 - has 'longitude_0' -> renaming coords...
# Checking coords of 1997 - has 'longitude_0' -> renaming coords...
# Checking coords of 1998 - has 'longitude_0' -> renaming coords...
# Checking coords of 2000 - has 'longitude_0' -> renaming coords...
# Checking coords of 2001 - has 'longitude_0' -> renaming coords...
# Checking coords of 2002 - has 'longitude_0' -> renaming coords...
# Checking coords of 2003 - has 'longitude_0' -> renaming coords...
# Checking coords of 2004 - has 'longitude_0' -> renaming coords...
# Checking coords of 2005 - has 'longitude_0' -> renaming coords...
# Checking coords of 2006 - has 'longitude_0' -> renaming coords...
# Checking coords of 2007 - has 'longitude_0' -> renaming coords...
# Checking coords of 2008 - has 'longitude_0' -> renaming coords...
# Checking coords of 2009 - has 'longitude_0' -> renaming coords...
# Checking coords of 2010 - has 'longitude_0' -> renaming coords...
# Checking coords of 2011 - has 'longitude_0' -> renaming coords...
# Checking coords of 2012 - has 'longitude_0' -> renaming coords...
# Checking coords of 2013 - has 'longitude_0' -> renaming coords...
# Checking coords of 2014 - has 'longitude_0' -> renaming coords...
# Checking coords of 2015 - has 'longitude_0' -> renaming coords...
# Checking coords of 2016 - has 'longitude_0' -> renaming coords...
# Checking coords of 2017 - has 'longitude_0' -> renaming coords...
# Checking coords of 2018 - has 'longitude_0' -> renaming coords...

# %%
con_phases_vas_xr = get_year_2phases_xr(con_year_vas_xr_map, con_year_vas_xr_map, phase_dim='time')
# Out:
# Checking coords of 1981 - has 'longitude_0' -> renaming coords...
# Checking coords of 1982 - has 'longitude_0' -> renaming coords...
# Checking coords of 1983 - has 'longitude_0' -> renaming coords...
# Checking coords of 1984 - has 'longitude_0' -> renaming coords...
# Checking coords of 1985 - has 'longitude_0' -> renaming coords...
# Checking coords of 1986 - has 'longitude_0' -> renaming coords...
# Checking coords of 1987 - has 'longitude_0' -> renaming coords...
# Checking coords of 1988 - has 'longitude_0' -> renaming coords...
# Checking coords of 1989 - has 'longitude_0' -> renaming coords...
# Checking coords of 1990 - has 'longitude_0' -> renaming coords...
# Checking coords of 1991 - has 'longitude_0' -> renaming coords...
# Checking coords of 1992 - has 'longitude_0' -> renaming coords...
# Checking coords of 1993 - has 'longitude_0' -> renaming coords...
# Checking coords of 1994 - has 'longitude_0' -> renaming coords...
# Checking coords of 1996 - has 'longitude_0' -> renaming coords...
# Checking coords of 1997 - has 'longitude_0' -> renaming coords...
# Checking coords of 1998 - has 'longitude_0' -> renaming coords...
# Checking coords of 2000 - has 'longitude_0' -> renaming coords...
# Checking coords of 2001 - has 'longitude_0' -> renaming coords...
# Checking coords of 2002 - has 'longitude_0' -> renaming coords...
# Checking coords of 2003 - has 'longitude_0' -> renaming coords...
# Checking coords of 2004 - has 'longitude_0' -> renaming coords...
# Checking coords of 2005 - has 'longitude_0' -> renaming coords...
# Checking coords of 2006 - has 'longitude_0' -> renaming coords...
# Checking coords of 2007 - has 'longitude_0' -> renaming coords...
# Checking coords of 2008 - has 'longitude_0' -> renaming coords...
# Checking coords of 2009 - has 'longitude_0' -> renaming coords...
# Checking coords of 2010 - has 'longitude_0' -> renaming coords...
# Checking coords of 2011 - has 'longitude_0' -> renaming coords...
# Checking coords of 2012 - has 'longitude_0' -> renaming coords...
# Checking coords of 2013 - has 'longitude_0' -> renaming coords...
# Checking coords of 2014 - has 'longitude_0' -> renaming coords...
# Checking coords of 2015 - has 'longitude_0' -> renaming coords...
# Checking coords of 2016 - has 'longitude_0' -> renaming coords...
# Checking coords of 2017 - has 'longitude_0' -> renaming coords...
# Checking coords of 2018 - has 'longitude_0' -> renaming coords...

# %%
diff_phases_vas_xr = get_year_2phases_xr(diff_year_vas_xr_map, diff_year_vas_xr_map, phase_dim='event_month')
# Out:
# Checking coords of 1981 - has 'longitude_0' -> renaming coords...
# Checking coords of 1982 - has 'longitude_0' -> renaming coords...
# Checking coords of 1983 - has 'longitude_0' -> renaming coords...
# Checking coords of 1984 - has 'longitude_0' -> renaming coords...
# Checking coords of 1985 - has 'longitude_0' -> renaming coords...
# Checking coords of 1986 - has 'longitude_0' -> renaming coords...
# Checking coords of 1987 - has 'longitude_0' -> renaming coords...
# Checking coords of 1988 - has 'longitude_0' -> renaming coords...
# Checking coords of 1989 - has 'longitude_0' -> renaming coords...
# Checking coords of 1990 - has 'longitude_0' -> renaming coords...
# Checking coords of 1991 - has 'longitude_0' -> renaming coords...
# Checking coords of 1992 - has 'longitude_0' -> renaming coords...
# Checking coords of 1993 - has 'longitude_0' -> renaming coords...
# Checking coords of 1994 - has 'longitude_0' -> renaming coords...
# Checking coords of 1996 - has 'longitude_0' -> renaming coords...
# Checking coords of 1997 - has 'longitude_0' -> renaming coords...
# Checking coords of 1998 - has 'longitude_0' -> renaming coords...
# Checking coords of 2000 - has 'longitude_0' -> renaming coords...
# Checking coords of 2001 - has 'longitude_0' -> renaming coords...
# Checking coords of 2002 - has 'longitude_0' -> renaming coords...
# Checking coords of 2003 - has 'longitude_0' -> renaming coords...
# Checking coords of 2004 - has 'longitude_0' -> renaming coords...
# Checking coords of 2005 - has 'longitude_0' -> renaming coords...
# Checking coords of 2006 - has 'longitude_0' -> renaming coords...
# Checking coords of 2007 - has 'longitude_0' -> renaming coords...
# Checking coords of 2008 - has 'longitude_0' -> renaming coords...
# Checking coords of 2009 - has 'longitude_0' -> renaming coords...
# Checking coords of 2010 - has 'longitude_0' -> renaming coords...
# Checking coords of 2011 - has 'longitude_0' -> renaming coords...
# Checking coords of 2012 - has 'longitude_0' -> renaming coords...
# Checking coords of 2013 - has 'longitude_0' -> renaming coords...
# Checking coords of 2014 - has 'longitude_0' -> renaming coords...
# Checking coords of 2015 - has 'longitude_0' -> renaming coords...
# Checking coords of 2016 - has 'longitude_0' -> renaming coords...
# Checking coords of 2017 - has 'longitude_0' -> renaming coords...
# Checking coords of 2018 - has 'longitude_0' -> renaming coords...

# %% [markdown]
# ## Regridding con and diff temp to uas/vas

# %%
con_temp_lat_lon = con_phases_temp_xr.rename(longitude='lon', latitude='lat') 
con_temp_ds = con_temp_lat_lon.to_dataset(name='ts_0') 

diff_temp_lat_lon = diff_phases_temp_xr.rename(longitude='lon', latitude='lat') 
diff_temp_ds = diff_temp_lat_lon.to_dataset(name='ts_0')

# %%
ds_out = xr.Dataset(
    {
        "lat": (["lat"], np.arange(-53.0, -27.5, 0.5)),
        "lon": (["lon"], np.arange(135, 190, 0.5)),
    }
)

# %%
regridder_con = xe.Regridder(con_temp_ds, ds_out, "bilinear") # build regridder 
ds_con_temp = regridder_con(con_temp_ds) # apply regridder 
con_temp = ds_con_temp.ts_0

# %%
regridder_diff = xe.Regridder(diff_temp_ds, ds_out, "bilinear") # build regridder 
ds_diff_temp = regridder_diff(diff_temp_ds) # apply regridder 
#ds_diff_temp = ds_diff_temp.drop(('latitude', 'longitude'))
diff_temp = ds_diff_temp.ts_0

# %% [markdown]
# ## Changing con and diff uas/vas dims to lat/lon

# %%
con_uas = con_phases_uas_xr.rename(longitude='lon', latitude='lat') 
diff_uas = diff_phases_uas_xr.rename(longitude='lon', latitude='lat') 
con_vas = con_phases_vas_xr.rename(longitude='lon', latitude='lat') 
diff_vas = diff_phases_vas_xr.rename(longitude='lon', latitude='lat')

# %% [markdown]
# ## Diff uas and diff vas

# %%
diff_uas.isel(phase=0).mean(dim='time').plot()

# %%
diff_vas.isel(phase=0).mean(dim='time').plot()

# %%
## Zonal anomalous (AUS)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = diff_uas.isel(phase=0).mean(dim='time').plot.contourf(
    levels = np.arange(-3.125, 3.25, 0.25),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-3,4,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Windspeed [m/s]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)

plt.title('Anomalous zonal wind', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/zonal_anom_aus.png')

# %%
## Zonal anomalous (NZ)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 179, -48, -34], crs=ccrs.PlateCarree())      

contour = diff_uas.isel(phase=0).mean(dim='time').plot.contourf(
    levels = np.arange(-3.125, 3.25, 0.25),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-3,4,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Windspeed [m/s]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)

plt.title('Anomalous zonal wind', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/zonal_anom_nz.png')

# %%
## Meridional anomalous (AUS)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = diff_vas.isel(phase=0).mean(dim='time').plot.contourf(
    levels = np.arange(-1.125, 1.25, 0.25),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-1,1.5,0.5),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Windspeed [m/s]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)

plt.title('Anomalous meridional wind', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/meridional_anom_aus.png')

# %%
## Meridional anomalous (NZ)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 179, -48, -34], crs=ccrs.PlateCarree())      

contour = diff_vas.isel(phase=0).mean(dim='time').plot.contourf(
    levels = np.arange(-1.125, 1.25, 0.25),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-1,1.5,0.5),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Windspeed [m/s]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)

plt.title('Anomalous meridional wind', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/meridional_anom_nz.png')

# %% [markdown]
# ## Mean uas and mean vas

# %%
con_uas.isel(phase=0).mean(dim='time').plot()

# %%
con_vas.isel(phase=0).mean(dim='time').plot()

# %%
## Zonal mean (AUS)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = con_uas.isel(phase=0).mean(dim='time').plot.contourf(
    levels = np.arange(-3.25, 3.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-3,4,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Windspeed [m/s]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)

plt.title('Mean zonal wind', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/zonal_mean_aus.png')

# %%
## Zonal mean (NZ)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 179, -48, -34], crs=ccrs.PlateCarree())        

contour = con_uas.isel(phase=0).mean(dim='time').plot.contourf(
    levels = np.arange(-3.25, 3.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-3,4,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Windspeed [m/s]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)

plt.title('Mean zonal wind', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/zonal_mean_nz.png')

# %%
## Meridional mean (AUS)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = con_vas.isel(phase=0).mean(dim='time').plot.contourf(
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Windspeed [m/s]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)

plt.title('Mean meridional wind', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/meridional_mean_aus.png')

# %%
## Meridional mean (NZ)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 179, -48, -34], crs=ccrs.PlateCarree())        

contour = con_vas.isel(phase=0).mean(dim='time').plot.contourf(
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Windspeed [m/s]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)

plt.title('Mean meridional wind', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/meridional_mean_nz.png')

# %% [markdown]
# ## Con temp x Diff uas

# %%
temp_con_buildup_xr = con_temp.isel(phase=0)
## shift longitude by 1 (recheck if direction is correct)
temp_con_buildup_shift_xr = temp_con_buildup_xr.shift(lon=1)
temp_con_gradient = ((temp_con_buildup_xr - temp_con_buildup_shift_xr))/50000

# %%
temp_con_gradient.sel(lat=slice(-45, -32), lon=slice(143, 155)).mean(dim='time').plot()
#143, 155, -45, -32

# %%
temp_con_gradient.sel(lat=slice(-48, -34), lon=slice(165, 179)).mean(dim='time').plot()

# %%
## Mean temp gradient (AUS)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      


data_low = -2 * 10**-5
data_high = 2 * 10**-5
level_step = 1 * 10**-5
level_low = data_low - level_step/2
level_high = data_high + level_step

contour = temp_con_gradient.mean(dim='time').plot.contourf(
    levels = np.arange(level_low, level_high, level_step),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
label_step = 1 * 10**-5
label_low = data_low
label_high = data_high + label_step/2
cbar = plt.colorbar(
    contour,
    orientation="horizontal",
    ticks=np.arange(label_low, label_high, label_step),
    fraction=0.035,aspect=25, extend='both'
)
cbar.formatter.set_powerlimits((0, 0))
cbar.set_label(label=u'Temperature gradient [\u00B0C/m]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
cbar.ax.xaxis.offsetText.set_fontsize(16)

plt.title('Mean temperature gradient', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/mean_temp_gradient_aus2.png')

# %%
## Mean temp gradient (NZ)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 179, -48, -34], crs=ccrs.PlateCarree())      

data_low = -2 * 10**-5
data_high = 2 * 10**-5
level_step = 1 * 10**-5
level_low = data_low - level_step/2
level_high = data_high + level_step

contour = temp_con_gradient.mean(dim='time').plot.contourf(
    levels = np.arange(level_low, level_high, level_step),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
label_step = 1 * 10**-5
label_low = data_low
label_high = data_high + label_step/2
cbar = plt.colorbar(
    contour,
    orientation="horizontal",
    ticks=np.arange(label_low, label_high, label_step),
    fraction=0.035,aspect=25, extend='both'
)
cbar.formatter.set_powerlimits((0, 0))
cbar.set_label(label=u'Temperature gradient [\u00B0C/m]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
cbar.ax.xaxis.offsetText.set_fontsize(16)

plt.title('Mean temperature gradient', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/mean_temp_gradient_nz2.png')

# %%
con_temp_diff_uas = temp_con_gradient*diff_uas.isel(phase=0)

# %%
con_temp_diff_uas.mean(dim='time').plot()

# %%
## Con temp x Diff uas (AUS)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = (con_temp_diff_uas.mean(dim='time')*86400).plot.contourf( ## 60x60x24 to calculate heat adv for a day
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/con_temp_diff_uas_aus_2.png')

# %%
## Con temp x Diff uas (NZ)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 180, -50, -34], crs=ccrs.PlateCarree())      

contour = (con_temp_diff_uas.mean(dim='time')*86400).plot.contourf(
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/con_temp_diff_uas_nz_2.png')

# %% [markdown]
# ## Con temp x Diff vas

# %%
con_temp_diff_vas = temp_con_gradient*diff_vas.isel(phase=0)
(con_temp_diff_vas.mean(dim='time')*86400).plot()

# %%
## Con temp x Diff vas (AUS)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = (con_temp_diff_vas.mean(dim='time')*86400).plot.contourf( ## 60x60x24 to calculate heat adv for a day
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/con_temp_diff_vas_aus_2.png')

# %%
## Con temp x Diff vas (NZ)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 180, -50, -34], crs=ccrs.PlateCarree())      

contour = (con_temp_diff_vas.mean(dim='time')*86400).plot.contourf(
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/con_temp_diff_vas_nz_2.png')

# %% [markdown]
# ## Diff temp x Con uas

# %%
temp_diff_buildup_xr = diff_temp.isel(phase=0)#.mean(dim=('lat', 'lon')) ## to have a single pair of lat,lon dimensions
## shift longitude by 1 (recheck if direction is correct)
temp_diff_buildup_shift_xr = temp_diff_buildup_xr.shift(lon=1)
temp_diff_gradient = ((temp_diff_buildup_xr - temp_diff_buildup_shift_xr))/50000

# %%
temp_diff_gradient.sel(lat=slice(-45, -32), lon=slice(143, 155)).mean(dim='time').plot()

# %%
temp_diff_gradient.differentiate('lon').sel(lat=slice(-45, -32), lon=slice(143, 155)).mean(dim='time').plot()

# %%
(diff_temp_x/50000).sel(lat=slice(-45, -32), lon=slice(143, 155)).mean(dim='time').plot()

# %%
temp_diff_gradient.sel(lat=slice(-48, -34), lon=slice(165, 179)).mean(dim='time').plot()

# %%
## Anom temp gradient (AUS)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      


data_low = -2 * 10**-5
data_high = 2 * 10**-5
level_step = 1 * 10**-5
level_low = data_low - level_step/2
level_high = data_high + level_step

contour = temp_diff_gradient.mean(dim='time').plot.contourf(
    levels = np.arange(level_low, level_high, level_step),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
label_step = 1 * 10**-5
label_low = data_low
label_high = data_high + label_step/2
cbar = plt.colorbar(
    contour,
    orientation="horizontal",
    ticks=np.arange(label_low, label_high, label_step),
    fraction=0.035,aspect=25, extend='both'
)
cbar.formatter.set_powerlimits((0, 0))
cbar.set_label(label=u'Temperature gradient [\u00B0C/m]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
cbar.ax.xaxis.offsetText.set_fontsize(16)

plt.title('Anomalous temperature gradient', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/anom_temp_gradient_aus.png')

# %%
## Anom temp gradient (NZ)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 179, -48, -34], crs=ccrs.PlateCarree())      


data_low = -2 * 10**-5
data_high = 2 * 10**-5
level_step = 1 * 10**-5
level_low = data_low - level_step/2
level_high = data_high + level_step

contour = temp_diff_gradient.mean(dim='time').plot.contourf(
    levels = np.arange(level_low, level_high, level_step),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
label_step = 1 * 10**-5
label_low = data_low
label_high = data_high + label_step/2
cbar = plt.colorbar(
    contour,
    orientation="horizontal",
    ticks=np.arange(label_low, label_high, label_step),
    fraction=0.035,aspect=25, extend='both'
)
cbar.formatter.set_powerlimits((0, 0))
cbar.set_label(label=u'Temperature gradient [\u00B0C/m]', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
cbar.ax.xaxis.offsetText.set_fontsize(16)

plt.title('Anomalous temperature gradient', fontsize=18)                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/Plots/anom_temp_gradient_nz.png')

# %%
diff_temp_con_uas = temp_diff_gradient*con_uas.isel(phase=0)
(diff_temp_con_uas.mean(dim='time')*86400).plot()

# %%
## Diff temp x Con uas (AUS)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = (diff_temp_con_uas.mean(dim='time')*86400).plot.contourf( ## 60x60x24 to calculate heat adv for a day
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/diff_temp_con_uas_aus_2.png')

# %%
## Diff temp x Con uas (NZ)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 180, -50, -34], crs=ccrs.PlateCarree())      

contour = (diff_temp_con_uas.mean(dim='time')*86400).plot.contourf(
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/diff_temp_con_uas_nz_2.png')

# %% [markdown]
# ## Diff temp x Con vas

# %%
diff_temp_con_vas = temp_diff_gradient*con_vas.isel(phase=0)
(diff_temp_con_vas.mean(dim='time')*86400).plot()

# %%
## Diff temp x Con vas (AUS)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = (diff_temp_con_vas.mean(dim='time')*86400).plot.contourf( ## 60x60x24 to calculate heat adv for a day
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/diff_temp_con_vas_aus_2.png')

# %%
## Diff temp x Con vas (NZ)
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 180, -50, -34], crs=ccrs.PlateCarree())      

contour = (diff_temp_con_vas.mean(dim='time')*86400).plot.contourf(
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/diff_temp_con_vas_nz_2.png')

# %% [markdown]
# ## Martin

# %% [markdown]
# ### Anom temp gradient x Mean winds

# %%
diff_temp_x = diff_temp.isel(phase=0).differentiate('lon')
diff_temp_y = diff_temp.isel(phase=0).differentiate('lat')

# %%
u_diff_temp_x = con_uas.isel(phase=0) * (diff_temp_x/50000) * 86400
v_diff_temp_y = con_vas.isel(phase=0) * (diff_temp_y/50000) * 86400

# %%
((u_diff_temp_x + v_diff_temp_y)*(-1)).sel(lat=slice(-45, -32), lon=slice(143, 155)).mean(dim='time').plot()

# %%
((u_diff_temp_x + v_diff_temp_y)*(-1)).sel(lat=slice(-50, -34), lon=slice(165, 180)).mean(dim='time').plot()

# %%
#abs_con_u = (xr.ufuncs.sqrt(con_uas.isel(phase=0)**2 + con_vas.isel(phase=0)**2)).mean(dim='time')
#abs_con_u
# Out:
# /local/e14/cp3790/tmp/ipykernel_101142/3044790629.py:1: FutureWarning: xarray.ufuncs is deprecated. Instead, use numpy ufuncs directly.
#   abs_con_u = (xr.ufuncs.sqrt(con_uas.isel(phase=0)**2 + con_vas.isel(phase=0)**2)).mean(dim='time')
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/xarray/core/dataarray.py:3078: FutureWarning: xarray.ufuncs is deprecated. Instead, use numpy ufuncs directly.
#   da = self.__array_wrap__(f(self.variable.data, *args, **kwargs))
# <xarray.DataArray (lat: 51, lon: 110)>
# dask.array<mean_agg-aggregate, shape=(51, 110), dtype=float32, chunksize=(51, 110), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float32 135.0 135.5 136.0 136.5 ... 188.0 188.5 189.0 189.5
#   * lat      (lat) float32 -53.0 -52.5 -52.0 -51.5 ... -29.5 -29.0 -28.5 -28.0
#     height   float64 10.0

# %%
con_uas_mean = con_uas.isel(phase=0).mean(dim='time')[::2, ::2]
con_vas_mean = con_vas.isel(phase=0).mean(dim='time')[::2, ::2]

# %%
abs_con_u = xr.ufuncs.sqrt(con_uas_mean**2 + con_vas_mean**2)[::2, ::2]
abs_con_u
# Out:
# /local/e14/cp3790/tmp/ipykernel_101142/1742962172.py:1: FutureWarning: xarray.ufuncs is deprecated. Instead, use numpy ufuncs directly.
#   abs_con_u = xr.ufuncs.sqrt(con_uas_mean**2 + con_vas_mean**2)[::2, ::2]
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/xarray/core/dataarray.py:3078: FutureWarning: xarray.ufuncs is deprecated. Instead, use numpy ufuncs directly.
#   da = self.__array_wrap__(f(self.variable.data, *args, **kwargs))
# <xarray.DataArray (lat: 26, lon: 55)>
# dask.array<getitem, shape=(26, 55), dtype=float32, chunksize=(26, 55), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float32 135.0 136.0 137.0 138.0 ... 186.0 187.0 188.0 189.0
#   * lat      (lat) float32 -53.0 -52.0 -51.0 -50.0 ... -31.0 -30.0 -29.0 -28.0
#     height   float64 10.0

# %%
## Diff temp x Con uas (AUS)

x = con_vas_mean['lon']
y = con_uas_mean['lat']
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = ((u_diff_temp_x + v_diff_temp_y)*(-1)).mean(dim='time').plot.contourf( ## 60x60x24 to calculate heat adv for a day
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')

q = ax.quiver(
    x, y,
    (con_uas_mean/abs_con_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    (con_vas_mean/abs_con_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    scale=10,
    units='height', headwidth=9, headlength=8, headaxislength=6.5
)
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/MJ_diff_temp_mean_wind_aus_quiver.png')

# %%
## Diff temp x Con uas (NZ)

x = con_vas_mean['lon']
y = con_uas_mean['lat']

fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 180, -50, -34], crs=ccrs.PlateCarree())      

contour = ((u_diff_temp_x + v_diff_temp_y)*(-1)).mean(dim='time').plot.contourf(
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')

q = ax.quiver(
    x, y,
    (con_uas_mean/abs_con_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    (con_vas_mean/abs_con_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    scale=10,
    units='height', headwidth=9, headlength=8, headaxislength=6.5
)

cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/MJ_diff_temp_mean_wind_nz_quiver.png')

# %% [markdown]
# ### Mean temp gradient x Anom winds

# %%
con_temp_x = con_temp.isel(phase=0).differentiate('lon') #differentiate temperature along x axis
con_temp_y = con_temp.isel(phase=0).differentiate('lat') #differentiate temperature along y axis

# %%
u_con_temp_x = diff_uas.isel(phase=0) * (con_temp_x/50000) * 86400
v_con_temp_y = diff_vas.isel(phase=0) * (con_temp_y/50000) * 86400

# %%
diff_uas_mean = diff_uas.isel(phase=0).mean(dim='time')[::2, ::2]
diff_vas_mean = diff_vas.isel(phase=0).mean(dim='time')[::2, ::2]

# %%
abs_diff_u = xr.ufuncs.sqrt(diff_uas_mean**2 + diff_vas_mean**2)
abs_diff_u
# Out:
# /local/e14/cp3790/tmp/ipykernel_101142/44814704.py:1: FutureWarning: xarray.ufuncs is deprecated. Instead, use numpy ufuncs directly.
#   abs_diff_u = xr.ufuncs.sqrt(diff_uas_mean**2 + diff_vas_mean**2)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/xarray/core/dataarray.py:3078: FutureWarning: xarray.ufuncs is deprecated. Instead, use numpy ufuncs directly.
#   da = self.__array_wrap__(f(self.variable.data, *args, **kwargs))
# <xarray.DataArray (lat: 26, lon: 55)>
# dask.array<sqrt, shape=(26, 55), dtype=float32, chunksize=(26, 55), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float32 135.0 136.0 137.0 138.0 ... 186.0 187.0 188.0 189.0
#   * lat      (lat) float32 -53.0 -52.0 -51.0 -50.0 ... -31.0 -30.0 -29.0 -28.0
#     height   float64 10.0

# %%
## Con temp x Diff winds (AUS)

x = diff_vas_mean['lon']
y = diff_uas_mean['lat']
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = ((u_con_temp_x + v_con_temp_y)*(-1)).mean(dim='time').plot.contourf( ## 60x60x24 to calculate heat adv for a day
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')

q = ax.quiver(
    x, y,
    (diff_uas_mean/abs_diff_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    (diff_vas_mean/abs_diff_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    scale=10,
    units='height', headwidth=9, headlength=8, headaxislength=6.5
)
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/MJ_con_temp_anom_wind_aus_quiver.png')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))

# %%
## Con temp x Diff winds (AUS)

x = diff_vas_mean['lon']
y = diff_uas_mean['lat']

fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 180, -50, -34], crs=ccrs.PlateCarree())      

contour = ((u_con_temp_x + v_con_temp_y)*(-1)).mean(dim='time').plot.contourf( ## 60x60x24 to calculate heat adv for a day
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')

q = ax.quiver(
    x, y,
    (diff_uas_mean/abs_diff_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    (diff_vas_mean/abs_diff_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    scale=10,
    units='height', headwidth=9, headlength=8, headaxislength=6.5
)

cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/MJ_con_temp_anom_wind_nz_quiver.png')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))

# %% [markdown]
# ### Anom temp gradient x Anom winds

# %%
u_diff_temp_diff_x = diff_uas.isel(phase=0) * (diff_temp_x/50000) * 86400
v_diff_temp_diff_y = diff_vas.isel(phase=0) * (diff_temp_y/50000) * 86400

# %%
## Diff temp x Diff winds (AUS)

x = diff_vas_mean['lon']
y = diff_uas_mean['lat']
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([143, 155, -45, -32], crs=ccrs.PlateCarree())      

contour = ((u_diff_temp_diff_x + v_diff_temp_diff_y)*(-1)).mean(dim='time').plot.contourf( ## 60x60x24 to calculate heat adv for a day
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')

q = ax.quiver(
    x, y,
    (diff_uas_mean/abs_diff_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    (diff_vas_mean/abs_diff_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    scale=10,
    units='height', headwidth=9, headlength=8, headaxislength=6.5
)
        
cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/MJ_diff_temp_anom_wind_aus_quiver.png')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))

# %%
## Diff temp x Diff winds (NZ)

x = diff_vas_mean['lon']
y = diff_uas_mean['lat']
    
fig, ax = plt.subplots(111, figsize=(16,9))
ax = plt.subplot(111, projection=ccrs.PlateCarree()) # Specifies the projection for the plots
                       
ax.set_extent([165, 180, -50, -34], crs=ccrs.PlateCarree())      

contour = ((u_diff_temp_diff_x + v_diff_temp_diff_y)*(-1)).mean(dim='time').plot.contourf( ## 60x60x24 to calculate heat adv for a day
    levels = np.arange(-5.25, 5.5, 0.5),
    cmap=plt.cm.get_cmap('bwr'),
    extend='both',
    add_colorbar=False
)
        
mask_mean = mask.mean(dim='time')

ax.contour(
    mask_mean.longitude, 
    mask_mean.latitude,
    mask_mean.values,
    levels=[0.5], 
    cmap='gray')

q = ax.quiver(
    x, y,
    (diff_uas_mean/abs_diff_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    (diff_vas_mean/abs_diff_u),#.isel(phase=0).mean(dim='time')[::2, ::2],
    scale=10,
    units='height', headwidth=9, headlength=8, headaxislength=6.5
)

cbar = plt.colorbar(contour, orientation="horizontal",ticks=np.arange(-5,6,1),
                    fraction=0.035,aspect=25, extend='both')
cbar.set_label(label=u'Heat advection (\u00B0C/day)', fontsize=16)  
cbar.ax.tick_params(labelsize=16)
                       
plt.savefig('/g/data/e14/cp3790/Charuni/ModelExperiment/MJ_diff_temp_anom_wind_nz_quiver.png')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.04/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
